# %%
print("Hello")
# Out:
# Hello

# %%
# !pip install tensorflow

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
## sentence 
sent = [
    'this glass of milk',
    'the glass of juice',
    'the cup of tea',
    ''
]
